# %%
#import file from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import joblib
import pandas as pd

x_train=pd.read_csv("drive/Shareddrives/major_project/data/x_train.csv")
y_train=pd.read_csv("drive/Shareddrives/major_project/data/y_train.csv")

# %%
from sklearn.ensemble import ExtraTreesRegressor
# First create the base model to tune
et = ExtraTreesRegressor()
et_model=et.fit(x_train,y_train.values.ravel())

# %%
#joblib.dump(et_model,"drive/Shareddrives/major_project/data/et_model.pkl")
# Out:
# ['drive/Shareddrives/major_project/data/et_model.pkl']
