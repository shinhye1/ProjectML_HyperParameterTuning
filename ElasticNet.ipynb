# %%
#import file from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import joblib
import pandas as pd

x_train=pd.read_csv("drive/Shareddrives/major_project/data/x_train.csv")
y_train=pd.read_csv("drive/Shareddrives/major_project/data/y_train.csv")

# %%
from sklearn.linear_model import ElasticNet
el = ElasticNet()
# fit
en_model=el.fit(x_train, y_train)

# %%
#joblib.dump(en_model,"drive/Shareddrives/major_project/data/en_model.pkl")
# Out:
# ['drive/Shareddrives/major_project/data/en_model.pkl']
