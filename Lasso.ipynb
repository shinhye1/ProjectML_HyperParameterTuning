# %%
#import file from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import joblib
import pandas as pd

x_train=pd.read_csv("drive/Shareddrives/major_project/data/x_train.csv")
y_train=pd.read_csv("drive/Shareddrives/major_project/data/y_train.csv")

# %%
from sklearn.linear_model import Lasso
la = Lasso(selection='random',tol=0.001)
# fit
la_model=la.fit(x_train, y_train)

# %%
#joblib.dump(la_model,"drive/Shareddrives/major_project/data/la_model.pkl")
# Out:
# ['drive/Shareddrives/major_project/data/la_model.pkl']
