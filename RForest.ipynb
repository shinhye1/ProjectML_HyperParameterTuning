# %%
#import file from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import joblib
import pandas as pd

x_train=pd.read_csv("drive/Shareddrives/major_project/data/x_train.csv")
y_train=pd.read_csv("drive/Shareddrives/major_project/data/y_train.csv")

# %%
from sklearn.ensemble import RandomForestRegressor
# First create the base model to tune
rf = RandomForestRegressor()
rf_model=rf.fit(x_train,y_train.values.ravel())

# %%
#joblib.dump(rf_model,"drive/Shareddrives/major_project/data/rf_model.pkl")
# Out:
# ['drive/Shareddrives/major_project/data/rf_model.pkl']
